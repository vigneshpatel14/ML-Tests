# %% [markdown]
# #1.Explain the importance of Functions.

# %% [markdown]
# Functions are important in programming because they allow us to:
#
# 1. Modularity:
#     Functions allow us to break down complex programs into smaller, more manageable pieces. This makes it easier to write, read, and maintain code.
#
# 2. Reusability:
#     Functions can be reused in multiple parts of a program or even in different programs. This saves time and effort, and it also helps to ensure consistency across different parts of a codebase.
#
# 3. Abstraction:
#     Functions allow us to abstract away the details of how a particular task is performed. This makes it easier to reason about the code and to understand how different parts of a program interact with each other.
#
# 4. Encapsulation:
#     Functions allow us to encapsulate related code and data into a single unit. This helps to improve the organization and maintainability of code.
# 5. Testing:
#     Functions can be easily tested independently of the rest of the program. This makes it easier to identify and fix bugs.

# %% [markdown]
# #2.Write a basic function to greet students.

# %%
def greet():
  print("Hello Students")
greet()
# Out:
# Hello Students

# %% [markdown]
# #3.What is the difference between print and return statements.

# %% [markdown]
# //Print
# Print the output to the console or other output stream
# it does not return any value
# can be used multiple times in a function
#
# //Return
# It returns a value from a function
# Can only be executed once in a function
# The returned value can be used in any statements or can be assigned to a variable

# %% [markdown]
# #4.What are *args and **kwargs

# %% [markdown]
# Args and kwargs are the parameteres we pass into a function , If we have more number of parameters to pass then we will use args by *args , we can pass any number of data types by this method , kwargs is also same but it stores Key - value pairs to access those we will use indexing like kwargs[i] .

# %% [markdown]
# #5.Explain the iterator function

# %% [markdown]
# Iterator function works like a loop , we can convert any type of data into iter ,
#  for example
#  if s = "pwskills",
#  then to make it iter we will use iter(s) , It will be converted into an iterator .
#  To access it we will use next(s),
#  It gives values one by one index how many times we call the iter .
#  We can iterate dictionary or tuple or list any thing.

# %% [markdown]
# # 6.Write a code that generates the squares of numbers from 1 to n using a generator.

# %%
def sq(n):
  for i in range(n):
    yield i **2
gen = sq(5)

# %%
next(gen)
# Out:
# 0

# %%
next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 4

# %% [markdown]
# #7.Write a code that generates palindromic numbers up to n using a generator

# %%
def pal(n):
  for i in range(n):
    if str(i) ==str(i)[::-1]:
      yield(i)
gen = pal(1000)

# %%
next(gen)
# Out:
# 0

# %%
next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 2

# %%
next(gen)
# Out:
# 3

# %% [markdown]
# #8.Write a code that generates even numbers from 2 to n using a generator

# %%
def eve(n):
  for i in range(n):
    if(i%2==0):
      yield i
g = eve(10)

# %%
next(g)
# Out:
# 0

# %%
next(g)
# Out:
# 2

# %%
next(g)
# Out:
# 4

# %%
next(g)
# Out:
# 6

# %%
next(g)
# Out:
# 8

# %% [markdown]
# #9.Write a code that generates powers of two up to n using a generator

# %%
def po(n):
  power = 1
  while power<=n:
    yield power
    power*=2

g = po(64)

# %%
next(g)
# Out:
# 1

# %%
next(g)
# Out:
# 2

# %%
next(g)
# Out:
# 4

# %%
next(g)
# Out:
# 8

# %%
next(g)
# Out:
# 16

# %%
next(g)
# Out:
# 32

# %%
next(g)
# Out:
# 64

# %% [markdown]
# #10.Write a code that generates prime numbers up to n using a generator

# %%
def p(n):
  for i in range(2,n):
    count = 0
    for j in range(2,i):
      if i%j == 0:
        count = count +1
    if count == 0:
      yield i
g = p(100)

# %%
next(g)
# Out:
# 2

# %%
next(g)
# Out:
# 3

# %%
next(g)
# Out:
# 5

# %%
next(g)
# Out:
# 7

# %%
next(g)
# Out:
# 11

# %%
next(g)
# Out:
# 13

# %% [markdown]
# #11.Write a code that uses a lambda function to calculate the sum of two numbers

# %%
a = lambda x,y:x+y

# %%
a(5,4)
# Out:
# 9

# %% [markdown]
# #12.Write a code that uses a lambda function to calculate the square of a given number

# %%
g = lambda x : x**2
g(10)
# Out:
# 100

# %% [markdown]
# #13.Write a code that uses a lambda function to check whether a given number is even or odd

# %%
e = lambda x: "even" if x%2==0 else "odd"
e(5)
# Out:
# 'odd'

# %%
e(10)
# Out:
# 'even'

# %% [markdown]
# #15.Write a code that uses a lambda function to concatenate two strings

# %%
st = lambda x,y : x+y
st("Pw","Skills")
# Out:
# 'PwSkills'

# %% [markdown]
# #16.Write a code that uses a lambda function to find the maximum of three given numbers

# %%
m = lambda x,y,z : x if x>y & x>z else y if y>z else z
m(4,5,6)
# Out:
# 6

# %% [markdown]
# #17.Write a code that generates the squares of even numbers from a given list

# %%
l = [1,2,3,4,5,6,7]
list(map(lambda x:x**2,l))
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %% [markdown]
# #18.Write a code that calculates the product of positive numbers from a given list

# %%
l = [1,2,3,-4,5,6,7,-8,-9]
product = 1
for i in l:
  if i >0:
    product*=i
print(product)
# Out:
# 1260

# %% [markdown]
# #19.Write a code that doubles the values of odd numbers from a given list

# %%
l =[1,2,3,4]
k=[]
for i in l:
  if i % 2 != 0:
    k.append(i+i)
  else:
    k.append(i)

k
# Out:
# [2, 2, 6, 4]

# %% [markdown]
# #20.Write a code that calculates the sum of cubes of numbers from a given list

# %%
l
sum = 0
for i in  l:
  sum = sum + (i*i*i)
sum
# Out:
# 100

# %% [markdown]
# #21.Write a code that filters out prime numbers from a given *list*

# %%
l = [1,2,3,4,5,6,7,8,9]

def p(n):
  for i in range(2,n):
    if n % i ==0:
      return False
    return True
list(filter(p,l))
# Out:
# [3, 5, 7, 9]

# %% [markdown]
# #22.Write a code that uses a lambda function to calculate the sum of two numbers

# %%
a = lambda x,y:x+y
a(5,4)
# Out:
# 9

# %% [markdown]
# #23.Write a code that uses a lambda function to calculate the square of a given number

# %%
g = lambda x : x**2
g(10)
# Out:
# 100

# %% [markdown]
# #24.Write a code that uses a lambda function to check whether a given number is even or odd

# %%
e = lambda x: "even" if x%2==0 else "odd"
e(5)
# Out:
# 'odd'

# %% [markdown]
# #25.Write a code that uses a lambda function to concatenate two strings

# %%
st = lambda x,y : x+y
st("Pw","Skills")
# Out:
# 'PwSkills'

# %% [markdown]
# #26.Write a code that uses a lambda function to find the maximum of three given numbers

# %%
m = lambda x,y,z : x if x>y & x>z else y if y>z else z
m(4,5,6)
# Out:
# 6

# %% [markdown]
# #27.What is encapsulation in OOP

# %% [markdown]
# Encapsulation in OOP is the process of bundling data and methods together into a single unit called an object. This helps to protect the data from being accessed or modified by unauthorized users. Encapsulation also helps to improve the modularity of code by allowing developers to create objects that can be easily reused in other programs.
#
# For example, consider a class called Student that represents a student in a school. The Student class could have data members such as name, age, and grade. It could also have methods such as get_name(), set_age(), and calculate_grade().
#
#
# Encapsulation helps to improve the security and maintainability of code by ensuring that data is only accessed and modified by authorized users. It also helps to improve the modularity of code by allowing developers to create objects that can be easily reused in other programs.

# %% [markdown]
# #28.Explain the use of access modifiers in Python classes

# %% [markdown]
# Access modifiers in Python classes are used to control the accessibility of attributes and methods of a class. There are three types of access modifiers in Python:
#
# * **Public:** Public attributes and methods are accessible from anywhere within the program.
# * **Protected:** Protected attributes and methods are accessible from within the class and its subclasses.
# * **Private:** Private attributes and methods are accessible only from within the class.

# %% [markdown]
# #29.What is inheritance in OOP

# %% [markdown]
# Inheritance is a fundamental concept in object-oriented programming  that allows the creation of new classes based on existing classes. It is a mechanism for code reuse and extension, enabling the creation of new classes that inherit the properties and methods of existing classes.
#
# Here's a simplified explanation of inheritance in OOP:
#
# **Parent Class (Base Class):**
#
# - The class from which other classes inherit is called the parent class or base class.
# - It defines the shared attributes and methods that will be inherited by its subclasses.
#
# **Child Class (Derived Class):**
#
# - The new class that inherits from the parent class is called the child class or derived class.
# - It inherits the attributes and methods of the parent class and can also define its own additional attributes and methods.

# %% [markdown]
# #30.Define polymorphism in OOP

# %% [markdown]
# The word polymorphism means having many forms. In programming, polymorphism means the same function name (but different signatures) being used for different types. The key difference is the data types and number of arguments used in function.
#
# In python,Polymorphism lets us define methods in the child class that have the same name as the methods in the parent class. In inheritance, the child class inherits the methods from the parent class. However, it is possible to modify a method in a child class that it has inherited from the parent class. This is particularly useful in cases where the method inherited from the parent class doesn’t quite fit the child class. In such cases, we re-implement the method in the child class. This process of re-implementing a method in the child class is known as Method Overriding.

# %% [markdown]
# #31.Explain method overriding in Python

# %% [markdown]
# Method overriding is an ability of any object-oriented programming language that allows a subclass or child class to provide a specific implementation of a method that is already provided by one of its super-classes or parent classes. When a method in a subclass has the same name, same parameters or signature and same return type(or sub-type) as a method in its super-class, then the method in the subclass is said to override the method in the super-class.

# %% [markdown]
# #32.Define a parent class Animal with a method make_sound that prints "Generic animal sound". Create a child class Dog inheriting from Animal with a method make_sound that prints "Woof!"

# %%
class Animal:
  def make_sound(self):
    print("Generic animal Sound")
class Dog(Animal):
  def make_sound(self):
    print("Woof")

# %%
dog = Dog()
dog.make_sound()
# Out:
# Woof

# %% [markdown]
# #33.Define a method move in the Animal class that prints "Animal moves". Override the move method in the Dog class to print "Dog runs

# %%
class Animal:
  def move(self):
    print("Animal Moves")
class Dog(Animal):
  def move(self):
    print("Dog Runs")
dog = Dog()
dog.move()
# Out:
# Dog Runs

# %% [markdown]
# #34.Create a class Mammal with a method reproduce that prints "Giving birth to live young." Create a class DogMammal inheriting from both Dog and Mammal

# %%
class Mammal:
  def reproduce(self):
    print("Giving birth to live young")
class DogMammal(Mammal,Dog):
  pass
dog_mammal = DogMammal()
dog_mammal.reproduce()
# Out:
# Giving birth to live young

# %%
dog_mammal.move()
# Out:
# Dog Runs

# %% [markdown]
# #35.Create a class GermanShepherd inheriting from Dog and override the make_sound method to print "Bark!

# %%
class GermanShepherd(Dog):
  def make_sound(self):
    print("Bark")


Gs = GermanShepherd()
Gs.make_sound()
# Out:
# Bark

# %% [markdown]
# #36.Define constructors in both the Animal and Dog classes with different initialization parameters

# %%
class Animal:
  def __init__(self,name):
    self.name = name
class Dog(Animal):
  def __init__(self,name,breed):
    super().__init__(name)
    self.breed = breed
dog = Dog("Rex", "German Shepherd")
print(dog.name)
print(dog.breed)
# Out:
# Rex
# German Shepherd

# %% [markdown]
# #37.What is abstraction in Python? How is it implemented

# %% [markdown]
# Abstraction in Python is a way of hiding the implementation details of a class from the user. This is done by providing a simple interface to the class that only exposes the necessary information. This allows the user to interact with the class without having to know how it works.
#
# Abstraction is a powerful tool that can be used to improve the modularity, security, and maintainability of code.

# %% [markdown]
# #38.Explain the importance of abstraction in object-oriented programming

# %% [markdown]
# Abstraction in object-oriented programming (OOP) is crucial because it simplifies complex systems by allowing programmers to focus on high-level functionality rather than low-level implementation details. By using abstract classes and interfaces, developers can define clear, simplified models of objects and their interactions, making the code more modular, easier to maintain, and more reusable.

# %% [markdown]
# #39.How are abstract methods different from regular methods in Python

# %% [markdown]
# Abstract methods differ from regular methods in Python in the following ways:
#
# Definition: Abstract methods are declared in abstract classes (using the ABC module and @abstractmethod decorator) and have no implementation. Regular methods have a complete implementation.
# Purpose: Abstract methods define a contract for subclasses, ensuring they implement specific methods. Regular methods provide specific functionality.
# Instantiation: Classes with abstract methods cannot be instantiated directly. Regular methods do not affect class instantiation.

# %% [markdown]
# #40.How can you achieve abstraction using interfaces in Python

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side ** 2

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

square = Square(5)
circle = Circle(3)

print(square.area())
print(circle.area())
# Out:
# 25
# 28.26

# %% [markdown]
# #41.Can you provide an example of how abstraction can be utilized to create a common interface for a group of related classes in Python

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass


class Square(Shape):
  def __init__(self,side):
    self.side = side

  def area(self):
    return self.side**2


class Circle(Shape):
  def __init__(self,radius):
    self.radius = radius

  def area(self):
    return 3.14 * self.radius **2


class Triangle(Shape):
  def __init__(self,base,height):
    self.base  = base
    self.height = height

  def area(self):
    return (self.base * self.height)/2


sq = Square(5)
tr = Triangle(3,4)
c = Circle(5)

print(sq.area())

print(tr.area())

print(c.area())
# Out:
# 25
# 6.0
# 78.5

# %% [markdown]
# #42.How does Python achieve polymorphism through method overriding

# %% [markdown]
# Polymorphism in Python is achieved through method overriding, which allows a subclass to provide a specific implementation of a method that is already defined in its superclass. This enables objects of different classes to be treated as objects of a common superclass, with the overridden methods providing specific behaviors for each subclass. Here’s how Python achieves polymorphism through method overriding

# %% [markdown]
# #43.Define a base class with a method and a subclass that overrides the method

# %%
class baseclass:
  def method(self):
    print("Base class")


class subclass(baseclass):
  def method(self):
    print("Subclass overriding base class")

s = subclass()

s.method()
# Out:
# Subclass overriding base class

# %% [markdown]
# #44.Define a base class and multiple subclasses with overridden methods

# %%
class Animal:
  def make_sound(self):
    print("Generic animal sound")

class Dog(Animal):
  def make_sound(self):
    print("Woof")

class Cat(Animal):
  def make_sound(self):
    print("Meow")

class Horse(Animal):
  def make_sound(self):
    print("Neigh")

dog = Dog()
cat = Cat()
horse = Horse()

dog.make_sound()
cat.make_sound()
horse.make_sound()
# Out:
# Woof
# Meow
# Neigh

# %% [markdown]
# #45.How does polymorphism improve code readability and reusability

# %% [markdown]
# Polymorphism improves code readability and reusability by:
#
# - **Simplifying code:** By using a common interface for related classes, polymorphism allows you to write code that works with different types of objects without having to worry about their specific implementations. This simplifies the code and makes it easier to understand.
# - **Promoting code reuse:** Polymorphism enables you to create code that can be reused in different contexts. For example, you can write a function that takes a Shape object as an argument and calculates its area. This function can be used with any subclass of Shape, such as Square, Circle, or Triangle, without modification.
# - **Enhancing maintainability:** Polymorphism makes code more maintainable by allowing you to change the implementation of a subclass without affecting the code that uses it. For example, if you need to change the way that the area of a Square is calculated, you can simply modify the area() method in the Square class. This change will not affect any of the code that uses the Square class.

# %% [markdown]
# #46.Describe how Python supports polymorphism with duck typing

# %% [markdown]
# Duck Typing in Python:
# Behavior-Based: Python focuses on an object's behavior (methods and attributes it supports) rather than its type or class hierarchy.
#
# No Explicit Interface: Objects are accepted based on their ability to respond to method calls and attribute accesses.
#
# Example: Different objects can be used interchangeably if they implement similar methods, without needing a common base class or interface.

# %% [markdown]
# #47.How do you achieve encapsulation in Python

# %% [markdown]
# Encapsulation in Python:
# Classes and Objects: Use classes to encapsulate data (attributes) and methods.
#
# Access Modifiers: Use naming conventions (_ for protected, __ for private) to indicate attribute visibility.
#
# Getter and Setter Methods: Optionally define methods to access and modify private attributes for controlled access.
#
# Benefits:
# Modularity: Bundles data and methods into coherent units (classes), enhancing code organization.
#
# Information Hiding: Controls access to data to protect implementation details and ensure data integrity.
#
# Flexibility: Python's dynamic nature allows for flexible implementation of encapsulation principles without strict enforcement.

# %% [markdown]
# #48.Can encapsulation be bypassed in Python? If so, how

# %% [markdown]
# Yes, encapsulation can be bypassed in Python using the following methods:
#
# 1. **Direct Attribute Access:** Private attributes can be accessed directly by using the object's `__dict__` attribute.
# 2. **Name Mangling:** Private attributes can be accessed indirectly using their mangled names, which are generated by Python to protect private attributes.
# 3. **Inheritance:** Private attributes can be accessed from subclasses, even though they are not directly visible to the subclass.

# %% [markdown]
# #49.Implement a class BankAccount with a private balance attribute. Include methods to deposit, withdraw,and check the balance

# %%
class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if self.__balance >= amount:
            self.__balance -= amount
        else:
            print("Insufficient funds")

    def check_balance(self):
        return self.__balance


account = BankAccount(1000)


account.deposit(500)


account.withdraw(200)


balance = account.check_balance()
print(f"Current balance: {balance}")
# Out:
# Current balance: 1300

# %% [markdown]
# #50.Develop a Person class with private attributes name and email, and methods to set and get the email

# %%
class Person:
    def __init__(self, name):
        self.__name = name
        self.__email = None

    def set_email(self, email):
        self.__email = email

    def get_email(self):
        return self.__email

    def get_name(self):
        return self.__name


person = Person("John Doe")
person.set_email("john.doe@example.com")


print(f"Name: {person.get_name()}")
print(f"Email: {person.get_email()}")
# Out:
# Name: John Doe
# Email: john.doe@example.com

# %% [markdown]
# #51.Why is encapsulation considered a pillar of object-oriented programming (OOP)

# %% [markdown]
# * **Data hiding:** Encapsulation helps to protect data from unauthorized access and modification by bundling data and methods together into a single unit called an object.
# * **Modularity:** Encapsulation promotes modularity by allowing developers to create self-contained units of code that can be easily reused in other programs.
# * **Code maintainability:** Encapsulation improves code maintainability by making it easier to understand and modify code.
# * **Information hiding:** Encapsulation helps to hide the implementation details of a class from its users, making it easier to change the implementation without affecting the code that uses it.

# %% [markdown]
# #52.Create a decorator in Python that adds functionality to a simple function by printing a message before and after the function execution

# %%
def pip(func):
  def wrapper():
    print("BEFORE")
    func()
    print("After")
  return wrapper
@pip
def say_hello():
  print("hello- printed between")
say_hello()
# Out:
# BEFORE
# hello- printed between
# After

# %% [markdown]
# #53.Modify the decorator to accept arguments and print the function name along with the message

# %%
def pip(msg):
  def wrapper(func):
    def w2(*args,**kwargs):
      print("BEFORE")
      print(func.__name__)
      func(*args,**kwargs)
      print(msg)
    return w2
  return wrapper
@pip("AFTER")
def say_hello():
  print("hello- printed between")
say_hello()
# Out:
# BEFORE
# say_hello
# hello- printed between
# AFTER

# %% [markdown]
# #54.Create two decorators, and apply them to a single function. Ensure that they execute in the order they are applied

# %%
def dec1(func):
  def wa1(*args,**kwargs):
    print("DEC 1")
    func(*args,**kwargs)
  return wa1


def dec2(func):
  def wa2(*args,**kwargs):
    print("DEC 2")
    func(*args,**kwargs)
  return wa2


@dec1
@dec2

def funcs():
  print("MY FUNCTION")

funcs()
# Out:
# DEC 1
# DEC 2
# MY FUNCTION

# %% [markdown]
# #55.Modify the decorator to accept and pass function arguments to the wrapped function

# %%
def dec1(func):
  def wa1(*args,**kwargs):
    print("DEC 1")
    func(*args,**kwargs)
  return wa1


def dec2(func):
  def wa2(*args,**kwargs):
    print("DEC 2")
    func(*args,**kwargs)
  return wa2


@dec2
@dec1

def funcs(a,b):
  print(a,b)

funcs(10,20)
# Out:
# DEC 2
# DEC 1
# 10 20

# %% [markdown]
# #56.Create a decorator that preserves the metadata of the original function

# %%
import functools

def preserve_metadata(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        return func(*args, **kwargs)
    return wrapper

@preserve_metadata
def my_function(a, b):
    """
    This function does something with the arguments a and b.
    """
    return a + b

print(my_function.__name__)  # Output: my_function
print(my_function.__doc__)  # Output: This function does something with the arguments a and b.
# Out:
# my_function
#
#     This function does something with the arguments a and b.

# %% [markdown]
# #57.Create a Python class `Calculator` with a static method `add` that takes in two numbers and returns their sum

# %%
class calculator:
  @staticmethod
  def a(x,y):
    return x + y

ca  = calculator()
ca.a(4,5)
# Out:
# 9

# %% [markdown]
# #58.Create a Python class `Employee` with a class `method get_employee_count` that returns the total number of employees created

# %%
class emp:
  sum = 0
  def __init__(self,name):
    self.name = name
    emp.sum = emp.sum+1
  @classmethod
  def get_emp(cls):
    return cls.sum

emp1 = emp("oe")

emp2 = emp("uhf")

emp.get_emp()
# Out:
# 2

# %% [markdown]
# #59.Create a Python class `StringFormatter` with a static method `reverse_string` that takes a string as input and returns its reverse

# %%
class Str:
  @staticmethod
  def rev(name):
    return name[::-1]
s = Str()
s.rev("AJAY")
# Out:
# 'YAJA'

# %% [markdown]
# #60.Create a Python class `Circle` with a class method `calculate_area` that calculates the area of a circle given its radius

# %%
class Cir:
  @staticmethod
  def cal(r):
    return 3.14*r*r
c = Cir()
c.cal(5)
# Out:
# 78.5

# %% [markdown]
# #61.Create a Python class `TemperatureConverter` with a static method `celsius_to_fahrenheit` that converts Celsius to Fahrenheit

# %%
class Temp:
  @staticmethod
  def ctof(c):
    return (9/5)*c + 32

t  = Temp()

t.ctof(100)
# Out:
# 212.0

# %% [markdown]
# #62.What is the purpose of the __str__() method in Python classes? Provide an example

# %%
#str method is used to return a string.

class Stu:
  def __init__(self):
    self.phone = 99129

  def __str__(self):
    return "THIS IS A STRING"

print(Stu())
# Out:
# THIS IS A STRING

# %% [markdown]
# #63.How does the __len__() method work in Python? Provide an example

# %%
#__len__ function is used return a length

class Stu:
  def __init__(self,name):
    self.name = name

  def __len__(self):
    return len(self.name)

l = Stu("pipwio")
print(len(l))
# Out:
# 6

# %% [markdown]
# #67.What is the purpose of a getter method in Python? Provide an example demonstrating the use of a getter method using property decorators

# %%
class Student:
    def __init__(self, name):
        self._name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, new_name):
        self._name = new_name

student = Student("John Doe")

print(student.name)

student.name = "Jane Doe"

print(student.name)
# Out:
# John Doe
# Jane Doe

# %% [markdown]
# #68.Explain the role of setter methods in Python. Demonstrate how to use a setter method to modify a class **attribute** using property decorators

# %%
class Student:
    def __init__(self, name):
        self._name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, new_name):
        self._name = new_name

student = Student("John Doe")

print(student.name)

student.name = "Jane Doe"

print(student.name)
# Out:
# John Doe
# Jane Doe

# %% [markdown]
# #69.What is the purpose of the @property decorator in Python? Provide an example illustrating its usage

# %%
#property decorator in Python is used to define a method as a property of a class


class Student:
    def __init__(self, name):
        self._name = name

    @property
    def name(self):
        return self._name

student = Student("John Doe")

print(student.name)
# Out:
# John Doe

# %% [markdown]
# #70.Explain the use of the @deleter decorator in Python property decorators. Provide a code example demonstrating its application

# %%
class Student:
    def __init__(self, name):
        self._name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, new_name):
        self._name = new_name

    @name.deleter
    def name(self):
        del self._name

student = Student("John Doe")

print(student.name)

del student.name
# Out:
# John Doe

# %% [markdown]
# #71.How does encapsulation relate to property decorators in Python? Provide an example showcasing encapsulation using property decorators

# %%
class Student:
    def __init__(self, name):
        self._name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, new_name):
        self._name = new_name

    @name.deleter
    def name(self):
        del self._name

student = Student("John Doe")

print(student.name)

del student.name
# Out:
# John Doe
